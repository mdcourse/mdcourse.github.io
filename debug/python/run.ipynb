# %%
import sys
sys.path.append("../../molecular-simulation/")
from main import MolecularDynamics
import numpy as np

x = MolecularDynamics(number_atoms=2,
                    Lx=12,
                    maximum_steps=20000,
                    dimensions= 3,
                    desired_temperature=300,
                    tau_temp = 100,
                    seed=42982,
                    thermo=1,
                    dump=1,
                    time_step=0.1,
                    provided_positions=np.array([[0, 0, 1], [0, 0, 5]]),
                    provided_velocities=np.array([[0, 0, 0.0045591837586768874], [0, 0, -0.0045591837586768874]]),
                    )
x.run()
# Out:
# step N temp epot ekin press vol
# 0 2 16.95 -9.78E-05 5.05E-02 1.33E+00 1.73E+03
# 1 2 17.23 -9.79E-05 5.14E-02 1.35E+00 1.73E+03
# 2 2 17.52 -9.80E-05 5.22E-02 1.37E+00 1.73E+03
# 3 2 17.8 -9.82E-05 5.31E-02 1.40E+00 1.73E+03
# 4 2 18.08 -9.83E-05 5.39E-02 1.42E+00 1.73E+03
# 5 2 18.36 -9.85E-05 5.47E-02 1.44E+00 1.73E+03
# 6 2 18.64 -9.86E-05 5.56E-02 1.46E+00 1.73E+03
# 7 2 18.93 -9.87E-05 5.64E-02 1.48E+00 1.73E+03
# 8 2 19.21 -9.89E-05 5.73E-02 1.51E+00 1.73E+03
# 9 2 19.49 -9.90E-05 5.81E-02 1.53E+00 1.73E+03
# 10 2 19.77 -9.92E-05 5.89E-02 1.55E+00 1.73E+03
# 11 2 20.05 -9.93E-05 5.98E-02 1.57E+00 1.73E+03
# 12 2 20.33 -9.95E-05 6.06E-02 1.60E+00 1.73E+03
# 13 2 20.61 -9.96E-05 6.14E-02 1.62E+00 1.73E+03
# 14 2 20.89 -9.98E-05 6.23E-02 1.64E+00 1.73E+03
# 15 2 21.17 -9.99E-05 6.31E-02 1.66E+00 1.73E+03
# 16 2 21.45 -1.00E-04 6.39E-02 1.68E+00 1.73E+03
# 17 2 21.72 -1.00E-04 6.48E-02 1.71E+00 1.73E+03
# 18 2 22.0 -1.00E-04 6.56E-02 1.73E+00 1.73E+03
# ...
