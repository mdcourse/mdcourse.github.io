# %%
import sys
sys.path.append("../../molecular-simulation/")
from main import MolecularDynamics

MolecularDynamics(number_atoms=25,
                    Lx=12,
                    maximum_steps=200000,
                    dimensions= 3,
                    desired_temperature=300,
                    tau_temp=100,
                    seed=41982,
                    thermo=500,
                    dump=500,
                    ).run()
# Out:
# step N temp epot ekin press vol
# 0 25 94.35 -3.17E-01 6.75E+00 1.73E+02 1.73E+03
# 500 25 299.23 -7.53E-02 2.14E+01 5.94E+02 1.73E+03
# 1000 25 301.65 -3.49E-01 2.16E+01 5.67E+02 1.73E+03
# 1500 25 301.3 -2.62E-01 2.16E+01 5.77E+02 1.73E+03
# 2000 25 299.11 -1.56E-01 2.14E+01 6.06E+02 1.73E+03
# 2500 25 299.78 -1.58E-01 2.14E+01 5.81E+02 1.73E+03
# 3000 25 299.9 -4.81E-02 2.15E+01 5.70E+02 1.73E+03
# 3500 25 301.44 -1.84E-01 2.16E+01 5.72E+02 1.73E+03
# 4000 25 299.99 -1.78E-01 2.15E+01 5.64E+02 1.73E+03
# 4500 25 300.28 -2.48E-01 2.15E+01 5.73E+02 1.73E+03
# 5000 25 299.54 -1.33E-01 2.14E+01 5.84E+02 1.73E+03
# 5500 25 301.12 -3.22E-01 2.15E+01 5.53E+02 1.73E+03
# 6000 25 302.83 -3.82E-01 2.17E+01 5.71E+02 1.73E+03
# 6500 25 299.72 -9.86E-02 2.14E+01 6.06E+02 1.73E+03
# 7000 25 301.07 -2.36E-01 2.15E+01 5.76E+02 1.73E+03
# 7500 25 299.23 -9.64E-02 2.14E+01 5.67E+02 1.73E+03
# 8000 25 299.61 -1.73E-01 2.14E+01 5.60E+02 1.73E+03
# 8500 25 300.38 -1.42E-01 2.15E+01 5.59E+02 1.73E+03
# 9000 25 300.17 -2.64E-01 2.15E+01 5.70E+02 1.73E+03
# 9500 25 300.61 -1.69E-01 2.15E+01 5.93E+02 1.73E+03
# 10000 25 301.13 -1.23E-01 2.15E+01 5.77E+02 1.73E+03
# 10500 25 299.84 -6.63E-02 2.15E+01 5.65E+02 1.73E+03
# 11000 25 299.78 -1.46E-01 2.14E+01 5.58E+02 1.73E+03
# 11500 25 299.42 -8.83E-02 2.14E+01 5.65E+02 1.73E+03
# 12000 25 300.4 -2.22E-01 2.15E+01 5.77E+02 1.73E+03
# 12500 25 298.85 -2.94E-01 2.14E+01 5.75E+02 1.73E+03
# 13000 25 301.5 -2.36E-01 2.16E+01 5.79E+02 1.73E+03
# 13500 25 298.98 -6.09E-02 2.14E+01 5.68E+02 1.73E+03
# 14000 25 300.09 -1.25E-01 2.15E+01 5.62E+02 1.73E+03
# 14500 25 299.68 -1.67E-01 2.14E+01 5.60E+02 1.73E+03
# 15000 25 300.63 -2.01E-01 2.15E+01 5.64E+02 1.73E+03
# 15500 25 300.43 -1.89E-01 2.15E+01 5.61E+02 1.73E+03
# 16000 25 301.91 -2.94E-01 2.16E+01 5.81E+02 1.73E+03
# 16500 25 300.68 -2.44E-01 2.15E+01 5.92E+02 1.73E+03
# 17000 25 302.55 -2.72E-01 2.16E+01 5.74E+02 1.73E+03
# 17500 25 300.8 -2.31E-01 2.15E+01 5.93E+02 1.73E+03
# 18000 25 298.8 -1.98E-01 2.14E+01 5.71E+02 1.73E+03
# 18500 25 300.36 -7.36E-02 2.15E+01 5.72E+02 1.73E+03
# 19000 25 300.31 -2.59E-01 2.15E+01 5.65E+02 1.73E+03
# 19500 25 300.04 -1.34E-01 2.15E+01 5.59E+02 1.73E+03
# 20000 25 299.1 -7.30E-02 2.14E+01 5.66E+02 1.73E+03
# 20500 25 299.28 -5.46E-02 2.14E+01 5.98E+02 1.73E+03
# 21000 25 299.19 -9.76E-02 2.14E+01 5.98E+02 1.73E+03
# 21500 25 287.32 7.62E-01 2.06E+01 7.90E+02 1.73E+03
# 22000 25 293.95 3.02E-01 2.10E+01 5.39E+02 1.73E+03
# 22500 25 299.07 -1.33E-01 2.14E+01 5.71E+02 1.73E+03
# 23000 25 301.35 -2.95E-01 2.16E+01 6.12E+02 1.73E+03
# 23500 25 301.88 -1.86E-01 2.16E+01 5.67E+02 1.73E+03
# 24000 25 293.53 2.88E-01 2.10E+01 5.10E+02 1.73E+03
# 24500 25 300.2 -1.05E-01 2.15E+01 5.62E+02 1.73E+03
# 25000 25 299.47 -1.27E-01 2.14E+01 5.59E+02 1.73E+03
# 25500 25 301.04 -1.52E-01 2.15E+01 5.79E+02 1.73E+03
# 26000 25 300.64 -1.80E-01 2.15E+01 5.59E+02 1.73E+03
# 26500 25 299.68 -1.36E-01 2.14E+01 5.81E+02 1.73E+03
# 27000 25 301.58 -3.34E-01 2.16E+01 5.80E+02 1.73E+03
# 27500 25 300.26 -1.51E-01 2.15E+01 3.52E+02 1.73E+03
# 28000 25 301.87 -2.77E-01 2.16E+01 5.78E+02 1.73E+03
# 28500 25 300.25 -2.37E-01 2.15E+01 5.65E+02 1.73E+03
# 29000 25 302.85 -4.37E-01 2.17E+01 5.58E+02 1.73E+03
# 29500 25 301.07 -2.55E-01 2.15E+01 5.64E+02 1.73E+03
# 30000 25 302.35 -3.63E-01 2.16E+01 5.62E+02 1.73E+03
# 30500 25 298.1 -7.26E-02 2.13E+01 5.68E+02 1.73E+03
# 31000 25 301.05 -2.99E-01 2.15E+01 5.82E+02 1.73E+03
# 31500 25 284.46 1.01E+00 2.04E+01 8.25E+02 1.73E+03
# 32000 25 299.95 -2.22E-01 2.15E+01 5.68E+02 1.73E+03
# 32500 25 302.53 -3.02E-01 2.16E+01 5.76E+02 1.73E+03
# 33000 25 300.93 -1.40E-01 2.15E+01 5.63E+02 1.73E+03
# 33500 25 299.09 -1.35E-01 2.14E+01 5.59E+02 1.73E+03
# 34000 25 299.18 -1.95E-01 2.14E+01 5.83E+02 1.73E+03
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 14
#       2 sys.path.append("../../molecular-simulation/")
#       3 from main import MolecularDynamics
#       5 MolecularDynamics(number_atoms=25,
#       6                     Lx=12,
#       7                     maximum_steps=200000,
#       8                     dimensions= 3,
#       9                     desired_temperature=300,
#      10                     tau_temp=100,
#      11                     seed=41982,
#      12                     thermo=500,
#      13                     dump=500,
# ---> 14                     ).run()
#
# File ~/Git/Personal/mdcourse.github.io/benchmark/python_25part_1.7nm3_300K_NVT/../../molecular-simulation/main.py:331, in MolecularDynamics.run(self)
#     329 """Perform the loop over time."""
#     330 for self.step in range(0, self.maximum_steps+1):
# --> 331     self.integrate_equation_of_motion()
#     332     self.wrap_in_box()
#     333     if self.tau_temp is not None:
#
# File ~/Git/Personal/mdcourse.github.io/benchmark/python_25part_1.7nm3_300K_NVT/../../molecular-simulation/main.py:347, in MolecularDynamics.integrate_equation_of_motion(self)
#     345 atoms_velocity_Dt2 = self.atoms_velocities + self.atoms_accelerations*self.time_step/2
#     346 self.atoms_positions = self.atoms_positions + atoms_velocity_Dt2*self.time_step
# --> 347 self.atoms_accelerations = self.evaluate_LJ_force()/self.atom_mass
#     348 self.atoms_velocities = atoms_velocity_Dt2 + self.atoms_accelerations*self.time_step/2
#     349 if self.tau_temp is not None:
#
# File ~/Git/Personal/mdcourse.github.io/benchmark/python_25part_1.7nm3_300K_NVT/../../molecular-simulation/main.py:298, in Utilities.evaluate_LJ_force(self)
#     296 box_size = np.diff(self.box_boundaries).reshape(3)
#     297 rij_xyz = (np.remainder(position_i - position_j + box_size/2., box_size) - box_size/2.).T
# --> 298 rij = np.sqrt(np.sum(rij_xyz**2))
#     299 if rij < self.cut_off:
#     300     dU_dr = 48/rij*(1/rij**12-0.5/rij**6)
#
# File <__array_function__ internals>:180, in sum(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2183, in _sum_dispatcher(a, axis, dtype, out, keepdims, initial, where)
#    2113     """
#    2114     Clip (limit) the values in an array.
#    2115
#    (...)
#    2178
#    2179     """
#    2180     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
# -> 2183 def _sum_dispatcher(a, axis=None, dtype=None, out=None, keepdims=None,
#    2184                     initial=None, where=None):
#    2185     return (a, out)
#    2188 @array_function_dispatch(_sum_dispatcher)
#    2189 def sum(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    2190         initial=np._NoValue, where=np._NoValue):
#
# KeyboardInterrupt:
