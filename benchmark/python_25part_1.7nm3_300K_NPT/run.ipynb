# %%
import sys
sys.path.append("../../molecular-simulation/")
from main import MolecularDynamics

MolecularDynamics(number_atoms=25,
                    Lx=12,
                    maximum_steps=200000,
                    dimensions= 3,
                    desired_temperature=300,
                    desired_pressure=200,
                    tau_temp=100,
                    tau_press=1000,
                    seed=41982,
                    thermo=500,
                    dump=500,
                    ).run()
# Out:
# 0.029167945148518164
# step N temp epot ekin press vol
# 0 25 94.35 -3.17E-01 6.75E+00 1.73E+02 1.73E+03
# 500 25 299.71 -6.73E-02 2.14E+01 2.37E+02 4.10E+03
# 1000 25 301.36 -1.16E-01 2.16E+01 2.09E+02 4.72E+03
# 1500 25 299.11 -3.31E-02 2.14E+01 2.01E+02 4.87E+03
# 2000 25 299.73 -6.44E-03 2.14E+01 2.03E+02 4.82E+03
# 2500 25 302.93 -1.38E-01 2.17E+01 2.07E+02 4.77E+03
# 3000 25 300.77 -1.24E-01 2.15E+01 1.99E+02 4.94E+03
# 3500 25 300.02 -3.38E-02 2.15E+01 2.07E+02 4.73E+03
# 4000 25 300.61 -1.52E-01 2.15E+01 1.97E+02 4.95E+03
# 4500 25 299.74 -3.33E-02 2.14E+01 1.98E+02 4.94E+03
# 5000 25 300.84 -5.43E-02 2.15E+01 2.07E+02 4.95E+03
# 5500 25 300.18 -4.60E-02 2.15E+01 1.98E+02 4.95E+03
# 6000 25 300.0 -1.71E-02 2.15E+01 1.98E+02 4.94E+03
# 6500 25 299.55 -9.05E-02 2.14E+01 1.98E+02 4.90E+03
# 7000 25 299.77 -1.05E-01 2.14E+01 1.98E+02 4.88E+03
# 7500 25 300.17 -7.99E-02 2.15E+01 2.00E+02 4.92E+03
# 8000 25 299.45 -4.46E-02 2.14E+01 1.98E+02 4.92E+03
# 8500 25 300.24 -9.27E-02 2.15E+01 1.96E+02 4.96E+03
# 9000 25 300.29 -5.16E-02 2.15E+01 1.98E+02 4.93E+03
# 9500 25 300.02 -2.93E-02 2.15E+01 2.00E+02 4.92E+03
# 10000 25 299.76 -5.32E-02 2.14E+01 2.03E+02 4.94E+03
# 10500 25 298.78 5.09E-02 2.14E+01 2.22E+02 4.83E+03
# 11000 25 300.7 -9.44E-02 2.15E+01 2.09E+02 4.66E+03
# 11500 25 299.82 -7.32E-02 2.14E+01 1.99E+02 4.89E+03
# 12000 25 300.11 -8.05E-02 2.15E+01 1.98E+02 4.92E+03
# 12500 25 295.28 2.88E-01 2.11E+01 2.29E+02 4.95E+03
# 13000 25 299.67 -5.18E-02 2.14E+01 2.01E+02 4.86E+03
# 13500 25 300.04 -1.90E-02 2.15E+01 2.00E+02 4.90E+03
# 14000 25 299.82 -7.90E-02 2.14E+01 2.05E+02 4.94E+03
# 14500 25 299.36 -7.25E-02 2.14E+01 1.98E+02 4.92E+03
# 15000 25 300.86 -1.06E-01 2.15E+01 2.01E+02 4.96E+03
# 15500 25 300.26 -6.57E-02 2.15E+01 1.97E+02 4.95E+03
# 16000 25 299.24 -6.67E-02 2.14E+01 1.96E+02 4.98E+03
# 16500 25 300.73 -8.33E-02 2.15E+01 2.02E+02 4.85E+03
# 17000 25 299.58 -3.21E-02 2.14E+01 1.98E+02 4.94E+03
# 17500 25 299.3 -1.50E-02 2.14E+01 1.99E+02 4.92E+03
# 18000 25 299.71 -2.43E-02 2.14E+01 7.44E+01 4.95E+03
# 18500 25 299.03 -5.74E-02 2.14E+01 2.00E+02 4.86E+03
# 19000 25 306.57 7.40E-03 2.19E+01 -6.53E+01 4.24E+03
# 19500 25 299.74 -3.79E-02 2.14E+01 2.04E+02 4.80E+03
# 20000 25 299.95 -9.57E-03 2.15E+01 1.99E+02 4.93E+03
# 20500 25 299.74 -2.09E-02 2.14E+01 1.98E+02 4.95E+03
# 21000 25 300.4 -4.59E-02 2.15E+01 1.98E+02 4.93E+03
# 21500 25 299.67 -1.89E-02 2.14E+01 2.08E+02 4.72E+03
# 22000 25 300.01 -1.86E-02 2.15E+01 2.02E+02 4.86E+03
# 22500 25 297.25 1.55E-01 2.13E+01 2.25E+02 4.90E+03
# 23000 25 300.23 -5.46E-02 2.15E+01 1.97E+02 4.94E+03
# 23500 25 300.31 -1.03E-01 2.15E+01 1.98E+02 4.92E+03
# 24000 25 299.58 -2.10E-02 2.14E+01 1.99E+02 4.91E+03
# 24500 25 299.59 -1.34E-02 2.14E+01 2.05E+02 4.77E+03
# 25000 25 299.59 -4.39E-03 2.14E+01 2.01E+02 4.88E+03
# 25500 25 298.56 -8.27E-03 2.14E+01 2.13E+02 4.92E+03
# 26000 25 299.59 -4.61E-02 2.14E+01 1.98E+02 4.94E+03
# 26500 25 301.0 -1.51E-01 2.15E+01 1.96E+02 4.94E+03
# 27000 25 300.05 -7.70E-02 2.15E+01 2.06E+02 4.96E+03
# 27500 25 298.88 -7.87E-02 2.14E+01 1.94E+02 5.00E+03
# 28000 25 300.37 -7.63E-02 2.15E+01 1.99E+02 4.97E+03
# 28500 25 301.88 -2.95E-01 2.16E+01 1.95E+02 4.98E+03
# 29000 25 299.87 -3.97E-02 2.15E+01 2.05E+02 4.79E+03
# 29500 25 301.65 -3.09E-01 2.16E+01 1.95E+02 4.96E+03
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/simon/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3442, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_162644/2595341265.py", line 16, in <module>
#     ).run()
#   File "/home/simon/Git/Personal/mdcourse.github.io/benchmark/python_25part_1.7nm3_300K_NPT/../../molecular-simulation/main.py", line 338, in run
#     self.update_dump()
#   File "/home/simon/Git/Personal/mdcourse.github.io/benchmark/python_25part_1.7nm3_300K_NPT/../../molecular-simulation/main.py", line 364, in apply_berendsen_barostat
#     self.box_boundaries *= scale
#   File "/home/simon/Git/Personal/mdcourse.github.io/benchmark/python_25part_1.7nm3_300K_NPT/../../molecular-simulation/main.py", line 266, in calculate_pressure
#   File "/home/simon/Git/Personal/mdcourse.github.io/benchmark/python_25part_1.7nm3_300K_NPT/../../molecular-simulation/main.py", line 300, in evaluate_LJ_force
#     dU_dr = 48/rij*(1/rij**12-0.5/rij**6)
#   File "<__array_function__ internals>", line 180, in sum
#   File "/home/simon/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py", line 2183, in _sum_dispatcher
#     def _sum_dispatcher(a, axis=None, dtype=None, out=None, keepdims=None,
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/simon/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2057, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/simon/.local/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/simon/.local/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/simon/.local/lib/python3.10/site-packages/IPython/core/ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/simon/.local/lib/python3.10/site-packages/IPython/core/ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "/home/simon/.local/lib/python3.10/site-packages/IPython/core/ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "/home/simon/.local/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/simon/.local/lib/python3.10/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "/home/simon/.local/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/simon/.local/lib/python3.10/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/home/simon/.local/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/simon/.local/lib/python3.10/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#   File "/home/simon/.local/lib/python3.10/site-packages/executing/executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
